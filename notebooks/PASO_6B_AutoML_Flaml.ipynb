# %%
# Celda 1 — Imports, paths y config
import os, warnings, joblib
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from flaml import AutoML
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import mlflow

# Paths
TRAIN = "../data/splits/train.parquet"
VAL   = "../data/splits/val.parquet"
TEST  = "../data/splits/test.parquet"  # opcional

EXPORT_DIR  = "../models/06_flaml"
REPORTS_DIR = "../reports"
os.makedirs(EXPORT_DIR, exist_ok=True)
os.makedirs(REPORTS_DIR, exist_ok=True)

# Columnas clave
Y_COL  = "num_bikes_available"
ID_COL = "station_id"
TS_COL = "ts_local"

# MLflow
MLFLOW_TRACKING_URI = "mlruns"
EXPERIMENT_NAME     = "ecobici_automl_flaml"
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment(EXPERIMENT_NAME)

# Config AutoML
TIME_BUDGET_SEC = 600   # podés subir/bajar
METRIC          = "rmse"
SEED            = 42

print("Entorno OK")
# Out:
# 2025/10/24 23:18:32 INFO mlflow.tracking.fluent: Experiment with name 'ecobici_automl_flaml' does not exist. Creating a new experiment.
# Entorno OK

# %%
# Celda 2 — Cargar splits
def load_df(p):
    assert os.path.exists(p), f"No existe {p}"
    return pd.read_parquet(p)

df_tr = load_df(TRAIN)
df_va = load_df(VAL)
df_te = load_df(TEST) if os.path.exists(TEST) else pd.DataFrame()

print("train:", df_tr.shape, "| val:", df_va.shape, "| test:", df_te.shape if not df_te.empty else "(no)")
df_tr[[ID_COL, TS_COL, Y_COL]].head(3)
# Out:
# train: (152463, 30) | val: (32774, 30) | test: (32712, 30)
#    station_id                  ts_local  num_bikes_available
# 0           2 2025-10-03 08:54:39-03:00                    7
# 1           2 2025-10-03 08:57:40-03:00                    7
# 2           2 2025-10-03 09:00:41-03:00                    7

# %%
# Celda 3 — Preparar X, y (solo numéricas; coherente con baseline)
def num_only(df: pd.DataFrame) -> pd.DataFrame:
    return df.select_dtypes(include=["number"]).copy()

def make_X_y(df: pd.DataFrame, y_col: str, id_col: str, ts_col: str):
    y = pd.to_numeric(df[y_col], errors="coerce").astype(float).values
    X = df.drop(columns=[c for c in [y_col, id_col, ts_col] if c in df.columns], errors="ignore")
    X = num_only(X).fillna(0.0)
    return X, y

Xtr, ytr = make_X_y(df_tr, Y_COL, ID_COL, TS_COL)
Xva, yva = make_X_y(df_va, Y_COL, ID_COL, TS_COL)

Xte = yte = None
if not df_te.empty:
    Xte, yte = make_X_y(df_te, Y_COL, ID_COL, TS_COL)

Xtr.shape, Xva.shape
# Out:
# ((152463, 20), (32774, 20))

# %%
# Celda 4 — Entrenamiento FLAML + logs a archivo (para monitorear con Celda 4b)
import os, sys, time, logging, joblib
from flaml import AutoML
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import mlflow

# --- Configuración de logs
log_path = os.path.join(EXPORT_DIR, "flaml.log")
for name in ["flaml", "flaml.automl"]:
    lg = logging.getLogger(name)
    lg.handlers = []
    lg.propagate = False
    fh = logging.FileHandler(log_path, mode="w")
    fh.setLevel(logging.INFO)
    lg.addHandler(fh)
    lg.setLevel(logging.INFO)

# --- Entrenamiento AutoML
automl = AutoML()

with mlflow.start_run(run_name="flaml_automl"):
    automl.fit(
        X_train=Xtr,
        y_train=ytr,
        task="regression",
        time_budget=TIME_BUDGET_SEC,   # segundos de límite total
        metric=METRIC,
        eval_method="holdout",
        X_val=Xva,
        y_val=yva,
        seed=SEED,
        log_file_name=log_path,        # los logs se guardan aquí
        n_jobs=-1,
    )

    # --- Evaluación en VALIDACIÓN ---
    yhat_va = np.clip(automl.predict(Xva), 0, None)
    rmse = mean_squared_error(yva, yhat_va, squared=False)
    mae  = mean_absolute_error(yva, yhat_va)
    r2   = r2_score(yva, yhat_va)

    mlflow.log_param("time_budget_sec", TIME_BUDGET_SEC)
    mlflow.log_param("metric", METRIC)
    mlflow.log_param("seed", SEED)
    mlflow.log_param("best_estimator", automl.best_estimator)
    mlflow.log_metric("val_rmse", rmse)
    mlflow.log_metric("val_mae",  mae)
    mlflow.log_metric("val_r2",   r2)

    MODEL_PATH = os.path.join(EXPORT_DIR, "flaml_automl.pkl")
    joblib.dump(automl, MODEL_PATH)
    mlflow.log_artifact(MODEL_PATH)

rmse, mae, r2, automl.best_estimator
# Out:
# [flaml.automl.logger: 10-24 23:49:16] {1679} INFO - task = regression
# [flaml.automl.logger: 10-24 23:49:16] {1687} INFO - Data split method: uniform
# [flaml.automl.logger: 10-24 23:49:16] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 10-24 23:49:16] {1788} INFO - Minimizing error metric: rmse
# [flaml.automl.logger: 10-24 23:49:16] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 10-24 23:49:16] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 10-24 23:49:16] {2344} INFO - Estimated sufficient time budget=3771s. Estimated necessary time budget=27s.
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.4s,	estimator lgbm's best error=3.5214,	best estimator lgbm's best error=3.5214
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.6s,	estimator lgbm's best error=3.5214,	best estimator lgbm's best error=3.5214
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.6s,	estimator xgboost's best error=4.9493,	best estimator lgbm's best error=3.5214
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 3, current learner xgboost
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.7s,	estimator xgboost's best error=4.9493,	best estimator lgbm's best error=3.5214
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 4, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.8s,	estimator extra_tree's best error=1.6440,	best estimator extra_tree's best error=1.6440
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 5, current learner rf
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 0.9s,	estimator rf's best error=1.5745,	best estimator rf's best error=1.5745
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 1.0s,	estimator lgbm's best error=3.5096,	best estimator rf's best error=1.5745
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 7, current learner rf
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 1.1s,	estimator rf's best error=1.5714,	best estimator rf's best error=1.5714
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 8, current learner rf
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 1.2s,	estimator rf's best error=1.0817,	best estimator rf's best error=1.0817
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 9, current learner rf
# [flaml.automl.logger: 10-24 23:49:17] {2391} INFO -  at 1.4s,	estimator rf's best error=0.8348,	best estimator rf's best error=0.8348
# [flaml.automl.logger: 10-24 23:49:17] {2218} INFO - iteration 10, current learner rf
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.5s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.6s,	estimator xgboost's best error=4.9350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.7s,	estimator extra_tree's best error=1.6440,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.8s,	estimator extra_tree's best error=1.1900,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.9s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 1.9s,	estimator extra_tree's best error=0.9151,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.0s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.1s,	estimator extra_tree's best error=0.7735,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.2s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.3s,	estimator extra_tree's best error=0.7735,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.4s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:18] {2391} INFO -  at 2.5s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:18] {2218} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 10-24 23:49:19] {2391} INFO -  at 2.5s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:19] {2218} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 10-24 23:49:19] {2391} INFO -  at 2.7s,	estimator rf's best error=0.7350,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:19] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:19] {2391} INFO -  at 2.7s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:19] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:19] {2391} INFO -  at 2.8s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7350
# [flaml.automl.logger: 10-24 23:49:19] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 10-24 23:49:20] {2391} INFO -  at 3.8s,	estimator rf's best error=0.7235,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:20] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:20] {2391} INFO -  at 3.9s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:20] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:20] {2391} INFO -  at 3.9s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:20] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:20] {2391} INFO -  at 4.4s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:20] {2218} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 10-24 23:49:21] {2391} INFO -  at 5.2s,	estimator rf's best error=0.7235,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:21] {2218} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.0s,	estimator rf's best error=0.7235,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 32, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.0s,	estimator xgb_limitdepth's best error=0.7742,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 33, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.1s,	estimator xgb_limitdepth's best error=0.7742,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 34, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.1s,	estimator xgb_limitdepth's best error=0.7428,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.3s,	estimator extra_tree's best error=0.7535,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 36, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:22] {2391} INFO -  at 6.4s,	estimator xgb_limitdepth's best error=0.7428,	best estimator rf's best error=0.7235
# [flaml.automl.logger: 10-24 23:49:22] {2218} INFO - iteration 37, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 6.4s,	estimator xgb_limitdepth's best error=0.6930,	best estimator xgb_limitdepth's best error=0.6930
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 38, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 6.5s,	estimator xgb_limitdepth's best error=0.6930,	best estimator xgb_limitdepth's best error=0.6930
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 39, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 6.8s,	estimator xgb_limitdepth's best error=0.6930,	best estimator xgb_limitdepth's best error=0.6930
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 40, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 6.9s,	estimator xgb_limitdepth's best error=0.6480,	best estimator xgb_limitdepth's best error=0.6480
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 41, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 7.1s,	estimator xgb_limitdepth's best error=0.6480,	best estimator xgb_limitdepth's best error=0.6480
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 42, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:23] {2391} INFO -  at 7.1s,	estimator xgb_limitdepth's best error=0.6480,	best estimator xgb_limitdepth's best error=0.6480
# [flaml.automl.logger: 10-24 23:49:23] {2218} INFO - iteration 43, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:24] {2391} INFO -  at 7.8s,	estimator extra_tree's best error=0.7535,	best estimator xgb_limitdepth's best error=0.6480
# [flaml.automl.logger: 10-24 23:49:24] {2218} INFO - iteration 44, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:24] {2391} INFO -  at 8.2s,	estimator xgb_limitdepth's best error=0.6480,	best estimator xgb_limitdepth's best error=0.6480
# [flaml.automl.logger: 10-24 23:49:24] {2218} INFO - iteration 45, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:25] {2391} INFO -  at 9.4s,	estimator xgb_limitdepth's best error=0.4790,	best estimator xgb_limitdepth's best error=0.4790
# [flaml.automl.logger: 10-24 23:49:25] {2218} INFO - iteration 46, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:26] {2391} INFO -  at 10.1s,	estimator xgb_limitdepth's best error=0.4790,	best estimator xgb_limitdepth's best error=0.4790
# [flaml.automl.logger: 10-24 23:49:26] {2218} INFO - iteration 47, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:28] {2391} INFO -  at 12.3s,	estimator xgb_limitdepth's best error=0.4075,	best estimator xgb_limitdepth's best error=0.4075
# [flaml.automl.logger: 10-24 23:49:28] {2218} INFO - iteration 48, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:29] {2391} INFO -  at 12.9s,	estimator xgb_limitdepth's best error=0.4075,	best estimator xgb_limitdepth's best error=0.4075
# [flaml.automl.logger: 10-24 23:49:29] {2218} INFO - iteration 49, current learner extra_tree
# [flaml.automl.logger: 10-24 23:49:29] {2391} INFO -  at 13.4s,	estimator extra_tree's best error=0.7498,	best estimator xgb_limitdepth's best error=0.4075
# [flaml.automl.logger: 10-24 23:49:29] {2218} INFO - iteration 50, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:40] {2391} INFO -  at 23.7s,	estimator xgb_limitdepth's best error=0.3763,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:49:40] {2218} INFO - iteration 51, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:46] {2391} INFO -  at 30.2s,	estimator xgb_limitdepth's best error=0.3763,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:49:46] {2218} INFO - iteration 52, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:49:59] {2391} INFO -  at 43.4s,	estimator xgb_limitdepth's best error=0.3763,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:49:59] {2218} INFO - iteration 53, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:00] {2391} INFO -  at 43.5s,	estimator xgboost's best error=4.9350,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:00] {2218} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 10-24 23:50:00] {2391} INFO -  at 44.0s,	estimator rf's best error=0.7235,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:00] {2218} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:00] {2391} INFO -  at 44.1s,	estimator lgbm's best error=1.0408,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:00] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:00] {2391} INFO -  at 44.2s,	estimator lgbm's best error=1.0408,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:00] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:00] {2391} INFO -  at 44.4s,	estimator lgbm's best error=0.7276,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:00] {2218} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:01] {2391} INFO -  at 44.6s,	estimator lgbm's best error=0.7276,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:01] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:01] {2391} INFO -  at 44.9s,	estimator lgbm's best error=0.6125,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:01] {2218} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:01] {2391} INFO -  at 45.1s,	estimator lgbm's best error=0.6125,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:01] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:01] {2391} INFO -  at 45.3s,	estimator lgbm's best error=0.5150,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:01] {2218} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:02] {2391} INFO -  at 45.5s,	estimator lgbm's best error=0.5150,	best estimator xgb_limitdepth's best error=0.3763
# [flaml.automl.logger: 10-24 23:50:02] {2218} INFO - iteration 63, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:02] {2391} INFO -  at 46.0s,	estimator lgbm's best error=0.3405,	best estimator lgbm's best error=0.3405
# [flaml.automl.logger: 10-24 23:50:02] {2218} INFO - iteration 64, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:02] {2391} INFO -  at 46.3s,	estimator lgbm's best error=0.3405,	best estimator lgbm's best error=0.3405
# [flaml.automl.logger: 10-24 23:50:02] {2218} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:03] {2391} INFO -  at 46.5s,	estimator lgbm's best error=0.3405,	best estimator lgbm's best error=0.3405
# [flaml.automl.logger: 10-24 23:50:03] {2218} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:03] {2391} INFO -  at 47.4s,	estimator lgbm's best error=0.3272,	best estimator lgbm's best error=0.3272
# [flaml.automl.logger: 10-24 23:50:03] {2218} INFO - iteration 67, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:08] {2391} INFO -  at 52.3s,	estimator lgbm's best error=0.3272,	best estimator lgbm's best error=0.3272
# [flaml.automl.logger: 10-24 23:50:08] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:09] {2391} INFO -  at 52.5s,	estimator lgbm's best error=0.3272,	best estimator lgbm's best error=0.3272
# [flaml.automl.logger: 10-24 23:50:09] {2218} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:09] {2391} INFO -  at 52.7s,	estimator lgbm's best error=0.3272,	best estimator lgbm's best error=0.3272
# [flaml.automl.logger: 10-24 23:50:09] {2218} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:13] {2391} INFO -  at 57.3s,	estimator lgbm's best error=0.3272,	best estimator lgbm's best error=0.3272
# [flaml.automl.logger: 10-24 23:50:13] {2218} INFO - iteration 71, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:18] {2391} INFO -  at 61.7s,	estimator lgbm's best error=0.2052,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:18] {2218} INFO - iteration 72, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 62.7s,	estimator lgbm's best error=0.2052,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 73, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 62.8s,	estimator xgboost's best error=1.0292,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 74, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 62.9s,	estimator xgboost's best error=1.0292,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 63.0s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 76, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 63.1s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 77, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 63.2s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 63.3s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 79, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:19] {2391} INFO -  at 63.4s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:19] {2218} INFO - iteration 80, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:20] {2391} INFO -  at 63.5s,	estimator xgboost's best error=0.6473,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:20] {2218} INFO - iteration 81, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:20] {2391} INFO -  at 63.6s,	estimator xgboost's best error=0.4616,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:20] {2218} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:20] {2391} INFO -  at 63.8s,	estimator xgboost's best error=0.4616,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:20] {2218} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:20] {2391} INFO -  at 64.2s,	estimator xgboost's best error=0.3843,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:20] {2218} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:21] {2391} INFO -  at 64.5s,	estimator xgboost's best error=0.3843,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:21] {2218} INFO - iteration 85, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:22] {2391} INFO -  at 65.5s,	estimator xgboost's best error=0.3443,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:22] {2218} INFO - iteration 86, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:25] {2391} INFO -  at 69.2s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:25] {2218} INFO - iteration 87, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:26] {2391} INFO -  at 70.1s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:26] {2218} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:32] {2391} INFO -  at 75.7s,	estimator lgbm's best error=0.2052,	best estimator lgbm's best error=0.2052
# [flaml.automl.logger: 10-24 23:50:32] {2218} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:36] {2391} INFO -  at 79.8s,	estimator lgbm's best error=0.2032,	best estimator lgbm's best error=0.2032
# [flaml.automl.logger: 10-24 23:50:36] {2218} INFO - iteration 90, current learner xgboost
# [flaml.automl.logger: 10-24 23:50:41] {2391} INFO -  at 85.4s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.2032
# [flaml.automl.logger: 10-24 23:50:41] {2218} INFO - iteration 91, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:43] {2391} INFO -  at 86.5s,	estimator lgbm's best error=0.2032,	best estimator lgbm's best error=0.2032
# [flaml.automl.logger: 10-24 23:50:43] {2218} INFO - iteration 92, current learner extra_tree
# [flaml.automl.logger: 10-24 23:50:43] {2391} INFO -  at 86.8s,	estimator extra_tree's best error=0.7498,	best estimator lgbm's best error=0.2032
# [flaml.automl.logger: 10-24 23:50:43] {2218} INFO - iteration 93, current learner lgbm
# [flaml.automl.logger: 10-24 23:50:58] {2391} INFO -  at 102.2s,	estimator lgbm's best error=0.1994,	best estimator lgbm's best error=0.1994
# [flaml.automl.logger: 10-24 23:50:58] {2218} INFO - iteration 94, current learner lgbm
# [flaml.automl.logger: 10-24 23:51:13] {2391} INFO -  at 117.0s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:51:13] {2218} INFO - iteration 95, current learner lgbm
# [flaml.automl.logger: 10-24 23:51:29] {2391} INFO -  at 133.1s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:51:29] {2218} INFO - iteration 96, current learner xgboost
# [flaml.automl.logger: 10-24 23:51:32] {2391} INFO -  at 135.6s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:51:32] {2218} INFO - iteration 97, current learner lgbm
# [flaml.automl.logger: 10-24 23:51:43] {2391} INFO -  at 147.4s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:51:43] {2218} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 10-24 23:52:06] {2391} INFO -  at 170.4s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:52:06] {2218} INFO - iteration 99, current learner lgbm
# [flaml.automl.logger: 10-24 23:52:18] {2391} INFO -  at 182.0s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:52:18] {2218} INFO - iteration 100, current learner lgbm
# [flaml.automl.logger: 10-24 23:52:43] {2391} INFO -  at 207.2s,	estimator lgbm's best error=0.1986,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:52:43] {2218} INFO - iteration 101, current learner extra_tree
# [flaml.automl.logger: 10-24 23:52:44] {2391} INFO -  at 207.6s,	estimator extra_tree's best error=0.7498,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:52:44] {2218} INFO - iteration 102, current learner xgboost
# [flaml.automl.logger: 10-24 23:52:45] {2391} INFO -  at 209.4s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.1986
# [flaml.automl.logger: 10-24 23:52:45] {2218} INFO - iteration 103, current learner lgbm
# [flaml.automl.logger: 10-24 23:52:59] {2391} INFO -  at 222.8s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:52:59] {2218} INFO - iteration 104, current learner xgboost
# [flaml.automl.logger: 10-24 23:53:08] {2391} INFO -  at 232.3s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:53:08] {2218} INFO - iteration 105, current learner lgbm
# [flaml.automl.logger: 10-24 23:53:23] {2391} INFO -  at 247.2s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:53:23] {2218} INFO - iteration 106, current learner xgboost
# [flaml.automl.logger: 10-24 23:53:28] {2391} INFO -  at 252.2s,	estimator xgboost's best error=0.2982,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:53:28] {2218} INFO - iteration 107, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:54:31] {2391} INFO -  at 314.6s,	estimator xgb_limitdepth's best error=0.3500,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:54:31] {2218} INFO - iteration 108, current learner lgbm
# [flaml.automl.logger: 10-24 23:55:09] {2391} INFO -  at 353.1s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:09] {2218} INFO - iteration 109, current learner extra_tree
# [flaml.automl.logger: 10-24 23:55:09] {2391} INFO -  at 353.5s,	estimator extra_tree's best error=0.7498,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:09] {2218} INFO - iteration 110, current learner xgboost
# [flaml.automl.logger: 10-24 23:55:12] {2391} INFO -  at 355.7s,	estimator xgboost's best error=0.2680,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:12] {2218} INFO - iteration 111, current learner lgbm
# [flaml.automl.logger: 10-24 23:55:14] {2391} INFO -  at 357.8s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:14] {2218} INFO - iteration 112, current learner extra_tree
# [flaml.automl.logger: 10-24 23:55:15] {2391} INFO -  at 358.6s,	estimator extra_tree's best error=0.7227,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:15] {2218} INFO - iteration 113, current learner extra_tree
# [flaml.automl.logger: 10-24 23:55:15] {2391} INFO -  at 359.0s,	estimator extra_tree's best error=0.7227,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:15] {2218} INFO - iteration 114, current learner xgb_limitdepth
# [flaml.automl.logger: 10-24 23:55:25] {2391} INFO -  at 368.9s,	estimator xgb_limitdepth's best error=0.3500,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:25] {2218} INFO - iteration 115, current learner lgbm
# [flaml.automl.logger: 10-24 23:55:37] {2391} INFO -  at 380.5s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:55:37] {2218} INFO - iteration 116, current learner lgbm
# [flaml.automl.logger: 10-24 23:56:13] {2391} INFO -  at 417.2s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:13] {2218} INFO - iteration 117, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:14] {2391} INFO -  at 417.5s,	estimator extra_tree's best error=0.6893,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:14] {2218} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:14] {2391} INFO -  at 418.3s,	estimator extra_tree's best error=0.6893,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:14] {2218} INFO - iteration 119, current learner lgbm
# [flaml.automl.logger: 10-24 23:56:35] {2391} INFO -  at 439.0s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:35] {2218} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:36] {2391} INFO -  at 439.9s,	estimator extra_tree's best error=0.6192,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:36] {2218} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:36] {2391} INFO -  at 440.3s,	estimator extra_tree's best error=0.6192,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:36] {2218} INFO - iteration 122, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:37] {2391} INFO -  at 440.9s,	estimator extra_tree's best error=0.5987,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:37] {2218} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 10-24 23:56:45] {2391} INFO -  at 448.8s,	estimator extra_tree's best error=0.5987,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:45] {2218} INFO - iteration 124, current learner lgbm
# [flaml.automl.logger: 10-24 23:56:50] {2391} INFO -  at 454.2s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:56:50] {2218} INFO - iteration 125, current learner lgbm
# [flaml.automl.logger: 10-24 23:57:00] {2391} INFO -  at 464.3s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:57:00] {2218} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 10-24 23:57:26] {2391} INFO -  at 490.0s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:57:26] {2218} INFO - iteration 127, current learner lgbm
# [flaml.automl.logger: 10-24 23:57:44] {2391} INFO -  at 508.4s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:57:44] {2218} INFO - iteration 128, current learner lgbm
# [flaml.automl.logger: 10-24 23:57:58] {2391} INFO -  at 522.0s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:57:58] {2218} INFO - iteration 129, current learner extra_tree
# [flaml.automl.logger: 10-24 23:58:06] {2391} INFO -  at 530.4s,	estimator extra_tree's best error=0.5260,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:58:06] {2218} INFO - iteration 130, current learner xgboost
# [flaml.automl.logger: 10-24 23:58:07] {2391} INFO -  at 531.0s,	estimator xgboost's best error=0.2680,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:58:07] {2218} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 10-24 23:58:24] {2391} INFO -  at 548.2s,	estimator xgboost's best error=0.2680,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:58:24] {2218} INFO - iteration 132, current learner extra_tree
# [flaml.automl.logger: 10-24 23:58:24] {2391} INFO -  at 548.3s,	estimator extra_tree's best error=0.5260,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:58:24] {2218} INFO - iteration 133, current learner lgbm
# [flaml.automl.logger: 10-24 23:59:35] {2391} INFO -  at 619.2s,	estimator lgbm's best error=0.1956,	best estimator lgbm's best error=0.1956
# [flaml.automl.logger: 10-24 23:59:35] {2493} INFO - selected model: LGBMRegressor(colsample_bytree=0.7708943707375012,
#               learning_rate=0.35817869858915824, max_bin=31,
#               min_child_samples=17, n_estimators=1, n_jobs=-1, num_leaves=8,
#               reg_alpha=0.3146792899260376, reg_lambda=560.0352055294726,
#               verbose=-1)
# [flaml.automl.logger: 10-24 23:59:35] {1930} INFO - fit succeeded
# [flaml.automl.logger: 10-24 23:59:35] {1931} INFO - Time taken to find the best model: 222.8288209438324
# (0.19552743623345384, 0.05782265137792971, 0.9984712642404889, 'lgbm')

# %%
# Celda 4c — Resumen de iteraciones FLAML (conteo, mejor modelo y tiempo total)
import os, re, datetime as dt
import pandas as pd
from pprint import pprint

log_path = os.path.join(EXPORT_DIR, "flaml.log")

summary = {
    "best_estimator": getattr(automl, "best_estimator", None),
    "best_loss_rmse": getattr(automl, "best_loss", None),  # ya está en escala de la métrica (rmse)
    "models_evaluated": list(getattr(automl, "best_config_per_estimator", {}).keys()),
}

# --- contar iteraciones y estimar duración leyendo el log ---
iters = 0
t0 = t1 = None
ts_pat = re.compile(r"(?P<mm>\d{2})-(?P<dd>\d{2}) (?P<hh>\d{2}):(?P<mi>\d{2}):(?P<ss>\d{2})")
iter_pat = re.compile(r"\biteration\s+\d+", re.IGNORECASE)
year = dt.datetime.now().year

if os.path.exists(log_path):
    with open(log_path, "r") as f:
        lines = f.readlines()
    # timestamps (primero y último)
    for line in lines:
        m = ts_pat.search(line)
        if m:
            t0 = dt.datetime(year, int(m["mm"]), int(m["dd"]), int(m["hh"]), int(m["mi"]), int(m["ss"]))
            break
    for line in reversed(lines):
        m = ts_pat.search(line)
        if m:
            t1 = dt.datetime(year, int(m["mm"]), int(m["dd"]), int(m["hh"]), int(m["mi"]), int(m["ss"]))
            break
    # iteraciones (conteo de líneas con "iteration k")
    iters = sum(1 for ln in lines if iter_pat.search(ln))

duration = (t1 - t0).total_seconds() if (t0 and t1) else None

summary.update({
    "iterations_seen": iters,
    "wall_time_sec": duration,
})

print("📝 Resumen FLAML")
pprint(summary)

# (opcional) tabla bonita
pd.DataFrame([summary])
# Out:
# 📝 Resumen FLAML
# {'best_estimator': 'lgbm',
#  'best_loss_rmse': 0.19555331710017126,
#  'iterations_seen': 0,
#  'models_evaluated': ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth'],
#  'wall_time_sec': None}
#   best_estimator  best_loss_rmse  \
# 0           lgbm        0.195553
#
#                                   models_evaluated  iterations_seen  \
# 0  [lgbm, rf, xgboost, extra_tree, xgb_limitdepth]                0
#
#   wall_time_sec
# 0          None

# %%
# Celda 5 — (Opcional) Evaluación en TEST
test_metrics = {}
if Xte is not None:
    yhat_te = automl.predict(Xte)
    yhat_te = np.clip(yhat_te, 0, None)

    rmse_t = mean_squared_error(yte, yhat_te, squared=False)
    mae_t  = mean_absolute_error(yte, yhat_te)
    r2_t   = r2_score(yte, yhat_te)

    test_metrics = {"test_rmse": rmse_t, "test_mae": mae_t, "test_r2": r2_t}
    print(f"TEST → RMSE={rmse_t:.4f} | MAE={mae_t:.4f} | R2={r2_t:.4f}")
else:
    print("No hay TEST → omitido.")
# Out:
# TEST → RMSE=0.4185 | MAE=0.0690 | R2=0.9932

# %%
# Celda 6 — Actualizar benchmark común (reports/automl_bench.csv)
bench_path = os.path.join(REPORTS_DIR, "automl_bench.csv")
row = {
    "framework": "flaml",
    "model_path": MODEL_PATH,
    "val_rmse": rmse,
    "val_mae": mae,
    "val_r2": r2,
    **test_metrics
}
bench = pd.DataFrame([row])

if os.path.exists(bench_path):
    prev = pd.read_csv(bench_path)
    bench = pd.concat([prev, bench], ignore_index=True)

bench.to_csv(bench_path, index=False)
bench.tail(5)
# Out:
#   framework                           model_path  val_rmse   val_mae  \
# 0     flaml  ../models/06_flaml/flaml_automl.pkl  0.195527  0.057823
#
#      val_r2  test_rmse  test_mae   test_r2
# 0  0.998471   0.418451  0.069021  0.993236

# %% [markdown]
# ### Celda 7 — Nota final e integración
#
#
# - Modelo FLAML: {MODEL_PATH}
# - Bench actualizado: {bench_path}
# - Runs en MLflow → usá: make mlflow-ui
#
# Próximo:
# - Notebook de comparativa (baseline RF vs PyCaret vs FLAML) leyendo reports/automl_bench.csv
# - Elegir ganador por menor val_rmse (empate → MAE, luego R²).
